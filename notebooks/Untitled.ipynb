# %%
import pandas as pd

df_cl = pd.read_csv("../data/tig_train.csv")

df_cl.head()
# Out:
#    user_reported  action_taken  label  word_count  char_count  \
# 0              0             1      0          14          73
# 1              0             0      0           3          16
# 2              0             0      0           4          14
# 3              1             1      1          75         339
# 4              0             0      0          10          49
#
#    avg_word_length  has_number  uppercase_ratio  punctuation_count  \
# 0         5.214286           0         0.000000                  9
# 1         5.333333           0         0.000000                  0
# 2         3.500000           0         0.000000                  0
# 3         4.520000           1         0.023599                  8
# 4         4.900000           0         0.000000                  3
#
#    has_harmful_keyword  ...  keyword_and_reported  type_comment  type_status  \
# 0                    0  ...                     0          True        False
# ...

# %%
df_cl.columns
# Out:
# Index(['user_reported', 'action_taken', 'label', 'word_count', 'char_count',
#        'avg_word_length', 'has_number', 'uppercase_ratio', 'punctuation_count',
#        'has_harmful_keyword', 'harmful_keyword_count', 'post_hour',
#        'post_dayofweek', 'is_weekend', 'post_month', 'post_year',
#        'days_since_post', 'user_is_reported', 'action_flagged', 'city_freq',
#        'is_major_city', 'report_action_mismatch', 'harmful_no_action',
#        'no_keyword_but_action', 'keyword_and_reported', 'type_comment',
#        'type_status', 'type_replay', 'type_post', 'type_share',
#        'length_very_short', 'length_short', 'length_medium', 'length_long'],
#       dtype='object')

# %%
df_cl.shape
# Out:
# (48, 34)

# %%
df_te = pd.read_csv("../data/tig_test.csv")

df_te.head()
# Out:
#    user_reported  action_taken  label  word_count  char_count  \
# 0              1             1      1          16          85
# 1              1             1      1           3          10
# 2              0             0      0           4          24
# 3              1             0      0           5          19
# 4              0             1      0           2           7
#
#    avg_word_length  has_number  uppercase_ratio  punctuation_count  \
# 0         5.312500           0              0.0                  7
# 1         3.333333           0              0.0                  0
# 2         6.000000           0              0.0                  0
# 3         3.800000           0              0.0                  0
# 4         3.500000           0              0.0                  0
#
#    has_harmful_keyword  ...  keyword_and_reported  type_comment  type_status  \
# 0                    0  ...                     0         False            0
# ...

# %%
df_te.shape
# Out:
# (17, 34)

# %%
df = pd.read_csv("../data/tig_meta_data.csv")

df.head()
# Out:
#     id             name        date  \
# 0  1.0    Biniam Girmay  2019-08-13
# 1  2.0  Almaz gual gere  2018-11-09
# 2  3.0      Hagos Berhe  2018-04-29
# 3  4.0            Selam  2020-01-05
# 4  5.0          Fikerte  2020-12-05
#
#                                          content    label  language post_type  \
# 0                   ነዚኦም አማ ብሓደ ጌርካ ምጉሓፎም አዩ ኔሩ   Harmful  Tigrinya      post
# 1             ደሓን ኩን ሓደ እተወላዊ ሰብ ናትካ ኣብ ሓበሬታ ኣለኹ  Neutral  Tigrinya   comment
# 2  ክሊቲኦም ህዝቢታት ብጣዕሚ ቅርሕንቲ አለዎም ዝፍታሕ ውን አይመስለንን?   Harmful  Tigrinya     share
# 3                          ሓበሬታ ለውጢ ሰላም ንምግባር ኣሎ  Neutral  Tigrinya      post
# 4          ቡዳ፤ጠቢብ፤በላዕቲ ሰብ አዮም ኮ አሳቶም አይትፈልጥን ዲካ?  Harmful  Tigrinya   comment
#
#   user_reported action_taken         city
# 0          True      Removed      Mekelle
# 1         False         none  Addis Ababa
# 2         False      Warning       Asmera
# 3          True         none        Adama
# 4         False      Removed     Bahr dar

# %%
df.columns
# Out:
# Index(['id', 'name', 'date', 'content', 'label', 'language', 'post_type',
#        'user_reported', 'action_taken', 'city'],
#       dtype='object')

# %%
df.shape
# Out:
# (65, 10)
